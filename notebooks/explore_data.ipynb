# %%
import pandas as pd

# %% [markdown]
# #
# - 앞에서 30까지의 변수는 결함 외 변수
# - 31개부터는 결함 변수

# %%
df = pd.read_csv("../data/DieCasting_Quality_Raw_Data.csv")
display(df.head())
print(df.columns)
print(df.columns[:31])
print(df.columns[31:])

# %%
df = pd.read_csv("../data/DieCasting_Quality_Raw_Data.csv", skiprows=1)
print(df.shape)
features = df.columns[:31]
defects = df.columns[31:]
display(df.head())

# %% [markdown]
# # 범주형 변수 확인

# %%
defects

# %%
df["id"].nunique()

# %%
df.groupby("Product_Type").size()

# %%
df.groupby("Shot").size()

# %%
df.head()
